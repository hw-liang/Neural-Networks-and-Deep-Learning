# %%
import language_model

# %%
model = language_model.train(16, 128)
# Out:
# Epoch 1
# Batch 100 Train CE 4.517
# Batch 200 Train CE 4.444
# Batch 300 Train CE 4.438
# Batch 400 Train CE 4.429
# Batch 500 Train CE 4.433
# Batch 600 Train CE 4.437
# Batch 700 Train CE 4.462
# Batch 800 Train CE 4.417
# Batch 900 Train CE 4.409
# Batch 1000 Train CE 4.411
# Running validation...
# Validation cross-entropy: 4.397
# Batch 1100 Train CE 4.351
# Batch 1200 Train CE 4.313
# Batch 1300 Train CE 4.235
# Batch 1400 Train CE 4.156
# Batch 1500 Train CE 4.106
# Batch 1600 Train CE 4.082
# Batch 1700 Train CE 4.045
# Batch 1800 Train CE 4.055
# Batch 1900 Train CE 4.018
# Batch 2000 Train CE 4.018
# Running validation...
# Validation cross-entropy: 3.955
# Batch 2100 Train CE 3.993
# Batch 2200 Train CE 3.917
# Batch 2300 Train CE 3.875
# Batch 2400 Train CE 3.828
# Batch 2500 Train CE 3.800
# Batch 2600 Train CE 3.768
# Batch 2700 Train CE 3.724
# Batch 2800 Train CE 3.630
# Batch 2900 Train CE 3.594
# Batch 3000 Train CE 3.581
# Running validation...
# ...

# %%
import pickle
data = pickle.load(open('data.pk', 'rb'))
data['vocab']
# Out:
# ['all',
#  'set',
#  'just',
#  'show',
#  'being',
#  'money',
#  'over',
#  'both',
#  'years',
#  'four',
#  'through',
#  'during',
#  'go',
#  'still',
#  'children',
#  'before',
#  'police',
#  'office',
#  'million',
#  'also',
#  'less',
#  'had',
#  ',',
#  'including',
#  'should',
#  'to',
#  'only',
#  'going',
#  'under',
#  'has',
#  'might',
#  'do',
#  'them',
#  'good',
#  'around',
#  'get',
#  'very',
#  'big',
#  'dr.',
#  'game',
#  'every',
#  'know',
#  'they',
#  'not',
#  'world',
#  'now',
#  'him',
#  'school',
#  'several',
#  'like',
#  'did',
#  'university',
#  'companies',
#  'these',
#  'she',
#  'team',
#  'found',
#  'where',
#  'right',
#  'says',
#  'people',
#  'house',
#  'national',
#  'some',
#  'back',
#  'see',
#  'street',
#  'are',
#  'year',
#  'home',
#  'best',
#  'out',
#  'even',
#  'what',
#  'said',
#  'for',
#  'federal',
#  'since',
#  'its',
#  'may',
#  'state',
#  'does',
#  'john',
#  'between',
#  'new',
#  ';',
#  'three',
# ...

# %%
model.predict_next_word('some','people','show')
# Out:
# some people show . Prob: 0.17166
# some people show , Prob: 0.09336
# some people show to Prob: 0.04007
# some people show it Prob: 0.03601
# some people show up Prob: 0.03443
# some people show out Prob: 0.03055
# some people show nt Prob: 0.02468
# some people show is Prob: 0.02401
# some people show for Prob: 0.02195
# some people show in Prob: 0.02107

# %%
language_model.find_occurrences('some','people','show')
# Out:
# The tri-gram "some people show" did not occur in the training set.

# %%
model.tsne_plot()
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  250 ...
# Mean value of sigma:  1.1523961030678929
# Iteration  10 : error is  13.772663452394399
# Iteration  20 : error is  13.33760168499727
# Iteration  30 : error is  13.36804425722637
# Iteration  40 : error is  14.981698821825722
# Iteration  50 : error is  14.895592980094587
# Iteration  60 : error is  15.563969315313248
# Iteration  70 : error is  15.315519089387255
# Iteration  80 : error is  15.580974190320063
# Iteration  90 : error is  15.39553460573516
# Iteration  100 : error is  15.0386212068136
# Iteration  110 : error is  1.946751293303796
# Iteration  120 : error is  1.3908316596369057
# Iteration  130 : error is  1.111222507680623
# Iteration  140 : error is  0.9727847608286889
# Iteration  150 : error is  0.8664607528200806
# Iteration  160 : error is  0.8192633752656384
# Iteration  170 : error is  0.7886587107226927
# ...

# %%
model.word_distance('government','political')
# Out:
# 1.15884188497023

# %%
model.word_distance('government','university')
# Out:
# 0.9842955644112472
